# %%
from src.providers.Spark import Spark

# %%
a = Spark()

# %%
df = a.session.read.format("iceberg").load("clockify_catalog.bronze.time_entries")

# %%
df.toPandas()
# Out:
#    billable costRate customFieldValues description hourlyRate  \
# 0     False  (0, R$)                []     AIRFLOW    (0, R$)
# 1      True  (0, R$)                []          FN    (0, R$)
# 2      True  (0, R$)                []          FN    (0, R$)
# 3      True  (0, R$)                []          FN    (0, R$)
# 4      True  (0, R$)                []          FN    (0, R$)
#
#                          id  isLocked kioskId                 projectId  \
# 0  681086462e56197b9fdc38a3     False    None  5e9f4704ea8094116e994d87
# 1  68108623685bcf6ccbc046a8     False    None  61e54e2ddc3256444ce00210
# 2  6808aa91762e83002bad3b0d     False    None  61e54e2ddc3256444ce00210
# 3  6808aa97aea83574e72ddd85     False    None  61e54e2ddc3256444ce00210
# 4  6810862b7e2ae746e8228f39     False    None  61e54e2ddc3256444ce00210
#
#   tagIds taskId                                       timeInterval     type  \
# 0     []   None  (PT1H30M, 2025-04-28T19:30:00Z, 2025-04-28T18:...  REGULAR
# ...
